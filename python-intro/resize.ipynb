# %%
import novice
picture = novice.open("flower.png")
print 'original size:', picture.size
picture
# Out:
# original size: (240L, 180L)
# Picture (format: png, path: c:\Users\drew\bootcamp_ubc\python-intro\flower.png, modified: False)

# %%
a=1
print 'a=',a
# Out:
# a= 1

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
math.cos(math.pi/2)
# Out:
# 6.123233995736766e-17

# %%
import math as m
m.sqrt(5)
# Out:
# 2.23606797749979

# %%
from math import cos
cos(math.pi/2)
# Out:
# 6.123233995736766e-17

# %%
whos
# Out:
# Variable   Type                          Data/Info
# --------------------------------------------------
# a          int                           1
# cos        builtin_function_or_method    <built-in function cos>
# m          module                        <module 'math' (built-in)>
# math       module                        <module 'math' (built-in)>
# novice     module                        <module 'novice' from 'novice.py'>
# picture    Picture                       Picture (format: png, pat<...>wer.png, modified: False)

# %%
picture
# Out:
# Picture (format: png, path: c:\Users\drew\bootcamp_ubc\python-intro\flower.png, modified: False)

# %%
foo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d3b07384d113> in <module>()
# ----> 1 foo
#
# NameError: name 'foo' is not defined

# %%
picture.size=(500,500)

# %%
picture
# Out:
# Picture (format: png, path: None, modified: True)

# %%
flower = novice.open('flower.png')
new_height = flower.height * (1000.0 / flower.width)
flower.size = (1000,new_height)
flower
# Out:
# Picture (format: png, path: None, modified: True)
